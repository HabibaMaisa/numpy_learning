# %% [markdown]
# # Manipulating array shapes

# %% [markdown]
# 1.reshape()

# %% [markdown]
# 2.resize()

# %% [markdown]
# 3.flatten()

# %% [markdown]
# 4.defining array shape

# %% [markdown]
# 5.revel()

# %% [markdown]
# #### reshape()

# %%
import numpy as np

# %%
a=np.array([[1,2,3],
            [4,5,6]])

# %%
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a.shape
# Out:
# (2, 3)

# %%
a_reshape= np.reshape(a,(3,2))

# %%
a_reshape
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
a_reshape.shape
# Out:
# (3, 2)

# %% [markdown]
# #### resize()

# %%
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a_resized=np.resize(a,(4,3))

# %%
a_resized
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# # revel()

# %%
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
b=np.random.randint(1,10,(2,3))

# %%
b
# Out:
# array([[1, 6, 7],
#        [8, 3, 5]], dtype=int32)

# %%
b_ravel=np.ravel(b)

# %%
b_ravel
# Out:
# array([1, 6, 7, 8, 3, 5], dtype=int32)

# %%
b
# Out:
# array([[1, 6, 7],
#        [8, 3, 5]], dtype=int32)

# %%
b_flattened=b.flatten()

# %%
b_flattened
# Out:
# array([1, 6, 7, 8, 3, 5], dtype=int32)

# %%
b_ravel[0]=0

# %%
b
# Out:
# array([[0, 6, 7],
#        [8, 3, 5]], dtype=int32)

# %%
b_flattened # return a copy of the array,always allocates a new memory
# Out:
# array([100,   6,   7,   8,   3,   5], dtype=int32)

# %%
b_flattened[0]=100

# %%
b_flattened
# Out:
# array([100,   6,   7,   8,   3,   5], dtype=int32)

# %%
b
# Out:
# array([[0, 6, 7],
#        [8, 3, 5]], dtype=int32)

# %% [markdown]
# #### defining array shape

# %%
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a.shape=(3,2)

# %%
a
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])
